# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
questions = pd.read_csv('dataedit.csv')
quizzes   = pd.read_csv('quiz.csv')
test1 = questions.loc[questions['quiz_id'] == 41]
test1["created_at"] = test1["created_at"].astype("datetime64")
test1.created_at.groupby([test1["created_at"].dt.day, test1["created_at"].dt.hour]).count().plot(kind="bar")
plt.xlabel("den hodina")
plt.xticks(rotation=60, fontsize=7)
plt.ylabel("# studentu")
plt.show()
# Out:
# /home/ujo/.local/lib/python3.6/site-packages/pandas/core/internals.py:3462: FutureWarning: Passing in 'datetime64' dtype with no frequency is deprecated and will raise in a future version. Please pass in 'datetime64[ns]' instead.
#   return self.apply('astype', dtype=dtype, **kwargs)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# <img src="data:image/png;base64,..." width="640">
